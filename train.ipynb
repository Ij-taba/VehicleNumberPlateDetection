# %%
from ultralytics import YOLO
model=YOLO("yolov8n.pt")
model.train(data="data.yaml",epochs=3)
# Out:
# Ultralytics 8.3.55  Python-3.11.4 torch-2.5.1+cpu CPU (Intel Core(TM) i5-8350U 1.70GHz)
# ...
